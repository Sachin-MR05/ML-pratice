# %%
import pandas as pd
import numpy as np

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fakhrealam0786/movielens-100k-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'movielens-100k-dataset' dataset.
# Path to dataset files: /kaggle/input/movielens-100k-dataset

# %%
import os
data = pd.read_csv(os.path.join(path, 'movielens_100k.csv'))

# %%
data.head()
# Out:
#    movie_id       title  year  \
# 0         1   toy story  1995
# 1         2   goldeneye  1995
# 2         3  four rooms  1995
# 3         4  get shorty  1995
# 4         5     copycat  1995
#
#                                            directors  \
# 0                                      John Lasseter
# 1                                    Martin Campbell
# 2  Allison Anders Alexandre Rockwell Robert Rodri...
# 3                                   Barry Sonnenfeld
# 4                                          Jon Amiel
#
#                                               actors  \
# 0  Tom Hanks Tim Allen Don Rickles Jim Varney Wal...
# 1  Pierce Brosnan Sean Bean Izabella Scorupco Fam...
# 2  Sammi Davis Amanda De Cadenet Valeria Golino M...
# 3  John Travolta Gene Hackman Rene Russo Danny De...
# 4  Sigourney Weaver Holly Hunter Dermot Mulroney ...
#
#                                       genres
# 0  Animation Adventure Comedy Family Fantasy
# ...
